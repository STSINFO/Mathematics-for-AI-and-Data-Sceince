# %%
# import jax.numpy as jnp
# from jax import grad
# import matplotlib.pyplot as plt
# import numpy as np

# def plot_f_dfdx(f,dfdx):
#     x=np.linspace(-5,5,100)
#     plt.plot(x,f(x),'r')
#     plt.plot(x,dfdx(f(x)),'b')
#     plt.show()


# def f(x):
#     return x**3+2*x**2+5
    
# def dfdx(f):
#     return grad(f)


# plot_f_dfdx(f,dfdx)

import jax.numpy as jnp
from jax import grad
import matplotlib.pyplot as plt
import numpy as np

def plot_f_dfdx(f, dfdx):
    x = np.linspace(-5, 5, 100)
    # evaluate both functions across the grid
    y_f = jnp.array([f(xi) for xi in x])
    y_dfdx = jnp.array([dfdx(xi) for xi in x])

    plt.plot(x, y_f, 'r', label='f(x)')
    plt.plot(x, y_dfdx, 'b', label="df/dx")
    plt.legend()
    plt.show()

# define function
def f(x):
    return x**3 + 2*x**2 + 5

# define derivative function
dfdx = grad(f)

# pass both functions to plot
plot_f_dfdx(f, dfdx)
